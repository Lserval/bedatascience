# %%
# ============================
# CONFIG 
# ============================
CONFIG = {
    "hidden_layers": [512, 256, 128, 64],
    "activation": "tanh",
    "dropout_rate": 0.2,
    "epochs": 70,
    "batch_size": 32,
    "optimizer": "adam",
    "loss": "categorical_crossentropy",
    "test_size": 0.1,
    "random_state": 42,
    # feature engineering
    "top_k_actions": 50,
    "use_browser_ohe": True,
    # file names
    "train_file": "train.csv",
    "test_file": "test.csv",
    "submission_file": "submission.csv",
    "save_model_path": "best_model.h5"
}

# ============================
# Imports
# ============================
import re, os
import numpy as np
import pandas as pd
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, classification_report
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

# ============================
# Utilities
# ============================
def read_ds(ds_name: str, has_label=True):
    sessions = []
    if not os.path.exists(ds_name):
        raise FileNotFoundError(f"{ds_name} not found")
    with open(ds_name, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line: 
                continue
            if (line.startswith('"') and line.endswith('"')) or (line.startswith("'") and line.endswith("'")):
                line = line[1:-1]
            parts = line.split(',')
            if has_label:
                util = parts[0]
                browser = parts[1] if len(parts) > 1 else ""
                actions = parts[2:]
            else:
                util = None
                browser = parts[0] if len(parts) > 1 else ""
                actions = parts[1:] if len(parts) > 1 else parts
            sessions.append({"util": util, "browser": browser, "parts": actions})
    return pd.DataFrame(sessions)

def filter_action(value: str):
    if not isinstance(value, str):
        return ""
    if value.startswith("t") and value[1:].isdigit():
        return ""
    for delim in ["(", "<", "$", "1"]:
        if delim in value:
            idx = value.find(delim)
            if idx > 0:
                value = value[:idx]
    return value.strip()

# ============================
# Feature engineering enrichi
# ============================
def session_to_features_enriched(parts):
    times, actions_clean, timeline = [], [], []
    current_time = 0
    for token in parts:
        tok = token.strip()
        m = re.match(r'^t(\d+)$', tok)
        if m:
            current_time = int(m.group(1))
            continue
        timeline.append((current_time, tok))
        a = filter_action(tok)
        if a:
            actions_clean.append(a)

    if not timeline:
        return {k:0.0 for k in [
            "nb_actions","nb_actions_unique","temps_total","moyenne_delta","std_delta",
            "delta_min","delta_max","delta_median","taux_repetition",
            "longueur_moyenne_sequence","longest_repeat","diversite_actions",
            "top3_ratio","unique_transitions","actions_joined"
        ]}

    # Temps et deltas
    times_list = [t for t,_ in timeline]
    deltas = [0.0] + [times_list[i]-times_list[i-1] for i in range(1,len(times_list))]
    nb_actions = len(timeline)
    nb_actions_unique = len(set(actions_clean))
    temps_total = float(times_list[-1]-times_list[0]) if len(times_list)>1 else 0.0
    moyenne_delta = float(np.mean(deltas))
    std_delta = float(np.std(deltas, ddof=1)) if len(deltas)>1 else 0.0
    delta_min = float(np.min(deltas))
    delta_max = float(np.max(deltas))
    delta_median = float(np.median(deltas))

    # Répétition & séquences
    rep_flags = [1 if actions_clean[i]==actions_clean[i-1] else 0 for i in range(1,len(actions_clean))]
    taux_repetition = float(np.mean(rep_flags)) if rep_flags else 0.0
    seqs, cur = [], 1
    for i in range(1,len(actions_clean)):
        if actions_clean[i]==actions_clean[i-1]: cur+=1
        else: seqs.append(cur); cur=1
    if actions_clean: seqs.append(cur)
    longueur_moy_seq = float(np.mean(seqs)) if seqs else 0.0
    longest_repeat = float(max(seqs)) if seqs else 0.0

    diversite = float(nb_actions_unique/nb_actions) if nb_actions>0 else 0.0

    # Fréquence top3 actions
    counts = Counter(actions_clean)
    top3_ratio = sum([counts[a] for a,_ in counts.most_common(3)]) / nb_actions

    # Transitions uniques (bigrammes)
    bigrams = list(zip(actions_clean[:-1], actions_clean[1:]))
    unique_transitions = len(set(bigrams))

    return {
        "nb_actions": nb_actions,
        "nb_actions_unique": nb_actions_unique,
        "temps_total": temps_total,
        "moyenne_delta": moyenne_delta,
        "std_delta": std_delta,
        "delta_min": delta_min,
        "delta_max": delta_max,
        "delta_median": delta_median,
        "taux_repetition": taux_repetition,
        "longueur_moyenne_sequence": longueur_moy_seq,
        "longest_repeat": longest_repeat,
        "diversite_actions": diversite,
        "top3_ratio": top3_ratio,
        "unique_transitions": unique_transitions,
        "actions_joined": " ".join([a.replace(" ","_") for a in actions_clean])
    }

def build_features_df(df_in, is_train=True):
    rows = []
    for _, row in df_in.iterrows():
        feats = session_to_features_enriched(row["parts"])
        out = feats.copy()
        out["util"] = row["util"] if is_train else None
        out["browser"] = row["browser"]
        rows.append(out)
    return pd.DataFrame(rows)

# ============================
# Pipeline principal
# ============================
def main_pipeline(config=CONFIG):
    print("Loading data...")
    train_raw = read_ds(config["train_file"], True)
    test_raw = read_ds(config["test_file"], False)

    print("Building enriched features...")
    train_basic = build_features_df(train_raw)
    test_basic = build_features_df(test_raw)

    train_basic = train_basic[train_basic["nb_actions"]>0].reset_index(drop=True)
    test_basic = test_basic[test_basic["nb_actions"]>0].reset_index(drop=True)
    print(f"Train: {len(train_basic)}, Test: {len(test_basic)}")

    # Vectorisation des actions
    vectorizer = CountVectorizer(max_features=config["top_k_actions"])
    vectorizer.fit(train_basic["actions_joined"].fillna(""))
    X_actions_train = vectorizer.transform(train_basic["actions_joined"].fillna("")).toarray()
    X_actions_test = vectorizer.transform(test_basic["actions_joined"].fillna("")).toarray()

    # Colonnes numériques enrichies
    numeric_cols = [
        "nb_actions","nb_actions_unique","temps_total","moyenne_delta","std_delta",
        "delta_min","delta_max","delta_median","taux_repetition",
        "longueur_moyenne_sequence","longest_repeat","diversite_actions",
        "top3_ratio","unique_transitions"
    ]
    scaler = StandardScaler()
    X_num_train = scaler.fit_transform(train_basic[numeric_cols].fillna(0).values)
    X_num_test = scaler.transform(test_basic[numeric_cols].fillna(0).values)

    # Encodage du navigateur
    if config["use_browser_ohe"]:
        ohe = OneHotEncoder(sparse_output=False, handle_unknown="ignore")
        X_browser_train = ohe.fit_transform(train_basic[["browser"]].fillna("UNK"))
        X_browser_test = ohe.transform(test_basic[["browser"]].fillna("UNK"))
    else:
        X_browser_train = np.zeros((len(train_basic),0))
        X_browser_test = np.zeros((len(test_basic),0))

    # Combinaison des features
    X_train_full = np.hstack([X_num_train, X_browser_train, X_actions_train])
    X_test_full = np.hstack([X_num_test, X_browser_test, X_actions_test])

    # Labels
    label_encoder = LabelEncoder()
    y_train = label_encoder.fit_transform(train_basic["util"].astype(str))
    n_classes = len(label_encoder.classes_)
    print(f"Number of classes: {n_classes}")

    # Split train / validation
    X_tr, X_val, y_tr, y_val = train_test_split(
        X_train_full, y_train, test_size=config["test_size"], random_state=config["random_state"], stratify=y_train
    )

    # Modèle MLP
    tf.keras.backend.clear_session()
    model = Sequential()
    input_dim = X_tr.shape[1]

    model.add(Dense(config["hidden_layers"][0], activation=config["activation"], input_shape=(input_dim,)))
    model.add(Dropout(config["dropout_rate"]))
    for neurons in config["hidden_layers"][1:]:
        model.add(Dense(neurons, activation=config["activation"]))
        model.add(Dropout(config["dropout_rate"]))
    model.add(Dense(n_classes, activation='softmax'))

    model.compile(optimizer=config["optimizer"], loss=config["loss"], metrics=['accuracy'])
    model.summary()

    # Entraînement + suivi F1
    checkpoint = ModelCheckpoint(config["save_model_path"], monitor='val_loss', save_best_only=True, verbose=1)
    f1_tr_list, f1_val_list = [], []
    best_f1_val = -1

    for epoch in range(config["epochs"]):
        model.fit(X_tr, tf.keras.utils.to_categorical(y_tr, n_classes), epochs=1,
                  batch_size=config["batch_size"],
                  validation_data=(X_val, tf.keras.utils.to_categorical(y_val, n_classes)),
                  callbacks=[checkpoint], verbose=0)

        y_pred_tr = np.argmax(model.predict(X_tr, verbose=0), axis=1)
        y_pred_val = np.argmax(model.predict(X_val, verbose=0), axis=1)

        f1_tr = f1_score(y_tr, y_pred_tr, average='macro', zero_division=0)
        f1_val = f1_score(y_val, y_pred_val, average='macro', zero_division=0)
        f1_tr_list.append(f1_tr)
        f1_val_list.append(f1_val)

        print(f"Epoch {epoch+1:02d}/{config['epochs']} — F1 train: {f1_tr:.4f} | F1 val: {f1_val:.4f}")

        if f1_val > best_f1_val:
            best_f1_val = f1_val
            model.save(config["save_model_path"])
            print(f"  -> New best F1 val {best_f1_val:.4f}, model saved.")

    # Plot F1
    plt.figure(figsize=(8,5))
    plt.plot(f1_tr_list, label="F1 train")
    plt.plot(f1_val_list, label="F1 val")
    plt.xlabel("Epoch"); plt.ylabel("F1 (macro)"); plt.legend(); plt.grid(True)
    plt.show()

    # Rapport final
    y_val_pred_final = np.argmax(model.predict(X_val, verbose=0), axis=1)
    val_classes = np.unique(y_val)
    print("\nClassification report (validation):")
    print(classification_report(
        y_val, y_val_pred_final, labels=val_classes,
        target_names=[label_encoder.classes_[i] for i in val_classes], zero_division=0
    ))

    # Prédictions test
    best_model = tf.keras.models.load_model(config["save_model_path"])
    y_test_pred_proba = best_model.predict(X_test_full, verbose=0)
    y_test_pred = np.argmax(y_test_pred_proba, axis=1)
    y_test_labels = label_encoder.inverse_transform(y_test_pred)

    df_sub = pd.DataFrame({"prediction": y_test_labels})
    df_sub.index = df_sub.index+1
    df_sub.to_csv(config["submission_file"], index_label="RowId")
    print(f"Submission saved to {config['submission_file']} ({len(df_sub)} rows)")

    return {
        "model": best_model,
        "label_encoder": label_encoder,
        "vectorizer": vectorizer,
        "scaler": scaler,
        "ohe_browser": (ohe if config["use_browser_ohe"] else None),
        "train_basic": train_basic,
        "test_basic": test_basic,
        "history_f1": (f1_tr_list, f1_val_list)
    }

if __name__ == "__main__":
    artifacts = main_pipeline(CONFIG)
# Out:
# Loading data...
# Building enriched features...
# Train: 3278, Test: 324
# Number of classes: 247
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │        31,744 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 247)            │        16,055 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 220,279 (860.46 KB)
#  Trainable params: 220,279 (860.46 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1: val_loss improved from None to 4.93117, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 01/70 — F1 train: 0.0195 | F1 val: 0.0142
#   -> New best F1 val 0.0142, model saved.
#
# Epoch 1: val_loss improved from 4.93117 to 4.23951, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 02/70 — F1 train: 0.0809 | F1 val: 0.0594
#   -> New best F1 val 0.0594, model saved.
#
# Epoch 1: val_loss improved from 4.23951 to 3.68328, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 03/70 — F1 train: 0.1385 | F1 val: 0.1140
#   -> New best F1 val 0.1140, model saved.
#
# Epoch 1: val_loss improved from 3.68328 to 3.22598, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 04/70 — F1 train: 0.1905 | F1 val: 0.1672
#   -> New best F1 val 0.1672, model saved.
#
# Epoch 1: val_loss improved from 3.22598 to 2.89975, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 05/70 — F1 train: 0.2480 | F1 val: 0.2416
#   -> New best F1 val 0.2416, model saved.
#
# Epoch 1: val_loss improved from 2.89975 to 2.62325, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 06/70 — F1 train: 0.2878 | F1 val: 0.2819
#   -> New best F1 val 0.2819, model saved.
#
# Epoch 1: val_loss improved from 2.62325 to 2.40651, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 07/70 — F1 train: 0.3382 | F1 val: 0.3191
#   -> New best F1 val 0.3191, model saved.
#
# Epoch 1: val_loss improved from 2.40651 to 2.25511, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 08/70 — F1 train: 0.3932 | F1 val: 0.3613
#   -> New best F1 val 0.3613, model saved.
#
# Epoch 1: val_loss improved from 2.25511 to 2.15927, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 09/70 — F1 train: 0.4130 | F1 val: 0.3564
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# Epoch 1: val_loss improved from 2.15927 to 1.98790, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 10/70 — F1 train: 0.4807 | F1 val: 0.4304
#   -> New best F1 val 0.4304, model saved.
#
# Epoch 1: val_loss improved from 1.98790 to 1.89617, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 11/70 — F1 train: 0.5088 | F1 val: 0.4589
#   -> New best F1 val 0.4589, model saved.
#
# Epoch 1: val_loss improved from 1.89617 to 1.87112, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 12/70 — F1 train: 0.5317 | F1 val: 0.4289
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# Epoch 1: val_loss improved from 1.87112 to 1.78710, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 13/70 — F1 train: 0.5560 | F1 val: 0.4488
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# Epoch 1: val_loss did not improve from 1.78710
# Epoch 14/70 — F1 train: 0.5814 | F1 val: 0.4234
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# Epoch 1: val_loss improved from 1.78710 to 1.67691, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 15/70 — F1 train: 0.6062 | F1 val: 0.5008
#   -> New best F1 val 0.5008, model saved.
#
# Epoch 1: val_loss improved from 1.67691 to 1.61524, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 16/70 — F1 train: 0.6464 | F1 val: 0.4942
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# Epoch 1: val_loss improved from 1.61524 to 1.58190, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 17/70 — F1 train: 0.6345 | F1 val: 0.4799
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# Epoch 1: val_loss improved from 1.58190 to 1.53406, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 18/70 — F1 train: 0.6701 | F1 val: 0.5286
#   -> New best F1 val 0.5286, model saved.
#
# Epoch 1: val_loss improved from 1.53406 to 1.48451, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 19/70 — F1 train: 0.6884 | F1 val: 0.5212
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# Epoch 1: val_loss did not improve from 1.48451
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 20/70 — F1 train: 0.7025 | F1 val: 0.5564
#   -> New best F1 val 0.5564, model saved.
#
# Epoch 1: val_loss improved from 1.48451 to 1.45444, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 21/70 — F1 train: 0.7226 | F1 val: 0.5463
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# Epoch 1: val_loss improved from 1.45444 to 1.42231, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 22/70 — F1 train: 0.7152 | F1 val: 0.5343
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# Epoch 1: val_loss did not improve from 1.42231
# Epoch 23/70 — F1 train: 0.6945 | F1 val: 0.5297
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# ...
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:98: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_true = type_of_target(y_true, input_name="y_true")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:99: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   type_pred = type_of_target(y_pred, input_name="y_pred")
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/utils/multiclass.py:79: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   ys_types = set(type_of_target(x) for x in ys)
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Classification report (validation):
#               precision    recall  f1-score   support
#
#          aho       0.00      0.00      0.00         1
#          ajo       0.00      0.00      0.00         1
#          akx       1.00      1.00      1.00         1
#          ald       1.00      0.50      0.67         2
#          ats       1.00      1.00      1.00         1
#          avt       0.67      1.00      0.80         2
#          azo       1.00      1.00      1.00         1
#          azx       0.00      0.00      0.00         1
#          bfg       1.00      1.00      1.00         2
#          bgn       1.00      1.00      1.00         3
#          blf       1.00      1.00      1.00         1
#          bos       0.00      0.00      0.00         1
#          bou       1.00      1.00      1.00         1
#          btl       1.00      1.00      1.00         1
#          byo       0.33      0.50      0.40         2
#          cbo       1.00      1.00      1.00         1
#          cec       0.00      0.00      0.00         1
#          cil       1.00      1.00      1.00         1
#          cje       0.00      0.00      0.00         1
#          cjr       0.50      0.80      0.62         5
#          ckl       1.00      1.00      1.00         1
#          cnh       0.50      1.00      0.67         1
#          cpn       1.00      1.00      1.00         1
#          cqp       1.00      1.00      1.00         1
#          cut       1.00      1.00      1.00         2
#          cvw       1.00      1.00      1.00         1
#          cxt       1.00      1.00      1.00         2
#          cxu       1.00      1.00      1.00         1
#          cyd       1.00      1.00      1.00         2
#          czi       1.00      0.50      0.67         2
#          dbi       0.00      0.00      0.00         1
#          deb       1.00      1.00      1.00         1
#          dfo       1.00      1.00      1.00         1
#          ebm       0.50      1.00      0.67         1
#          eoe       0.50      1.00      0.67         1
#          eqw       0.00      0.00      0.00         1
#          esu       1.00      1.00      1.00         1
#          eus       1.00      1.00      1.00         1
#          fal       1.00      1.00      1.00         1
#          fcq       1.00      1.00      1.00         1
#          fek       0.00      0.00      0.00         1
#          fgc       1.00      1.00      1.00         1
#          fgn       1.00      1.00      1.00         1
#          fjb       1.00      1.00      1.00         1
#          flj       0.50      0.50      0.50         4
#          fmz       0.00      0.00      0.00         1
#          fou       0.67      1.00      0.80         2
#          ftq       1.00      1.00      1.00         2
#          fuy       0.67      1.00      0.80         2
#          fuz       1.00      1.00      1.00         1
#          fvc       0.67      0.67      0.67         3
#          fwf       1.00      0.33      0.50         3
#          fwh       0.50      1.00      0.67         1
#          fyf       1.00      1.00      1.00         1
#          gcr       1.00      1.00      1.00         1
#          gid       1.00      0.50      0.67         2
#          gor       0.00      0.00      0.00         2
#          gtj       0.67      1.00      0.80         2
#          guh       0.33      0.50      0.40         2
#          gvp       0.00      0.00      0.00         1
#          gzi       1.00      1.00      1.00         1
#          hdz       1.00      1.00      1.00         1
#          hew       0.50      1.00      0.67         1
#          hfy       1.00      1.00      1.00         1
#          hjs       0.75      0.75      0.75         4
#          hll       0.00      0.00      0.00         1
#          hrj       1.00      1.00      1.00         1
#          hvh       0.00      0.00      0.00         1
#          hxt       0.00      0.00      0.00         1
#          hzx       0.67      1.00      0.80         2
#          iba       1.00      1.00      1.00         1
#          ien       1.00      1.00      1.00         1
#          iib       1.00      1.00      1.00         2
#          iju       1.00      1.00      1.00         1
#          iyf       0.00      0.00      0.00         1
#          jfm       1.00      0.50      0.67         2
#          jkc       0.00      0.00      0.00         1
#          jks       0.50      1.00      0.67         1
#          jmq       0.50      0.50      0.50         2
#          jpm       0.00      0.00      0.00         2
#          jqq       0.50      1.00      0.67         1
#          jrc       1.00      1.00      1.00         1
#          jxu       1.00      1.00      1.00         1
#          kbf       0.00      0.00      0.00         1
#          khv       1.00      1.00      1.00         1
#          kik       1.00      1.00      1.00         2
#          kks       0.50      0.67      0.57         3
#          kwi       1.00      0.67      0.80         3
#          kzt       1.00      1.00      1.00         1
#          lgd       1.00      0.50      0.67         2
#          lgz       0.60      1.00      0.75         3
#          lhd       0.33      1.00      0.50         1
#          lhr       0.50      1.00      0.67         1
#          lio       1.00      0.50      0.67         2
#          meh       1.00      1.00      1.00         2
#          mgs       0.00      0.00      0.00         1
#          mmm       0.00      0.00      0.00         2
#          mqo       1.00      1.00      1.00         1
#          muz       0.75      1.00      0.86         3
#          myl       1.00      1.00      1.00         1
#          ncb       0.00      0.00      0.00         2
#          nfh       1.00      1.00      1.00         1
#          ngs       0.50      0.50      0.50         2
#          nkb       0.00      0.00      0.00         1
#          nlm       1.00      1.00      1.00         1
#          npo       1.00      1.00      1.00         1
#          nqg       0.75      1.00      0.86         3
#          nrb       1.00      0.50      0.67         2
#          nsf       1.00      1.00      1.00         1
#          nuh       1.00      1.00      1.00         1
#          nwt       1.00      1.00      1.00         2
#          nyk       0.50      1.00      0.67         1
#          nzq       1.00      1.00      1.00         3
#          obm       1.00      1.00      1.00         1
#          oec       1.00      0.50      0.67         2
#          ofq       1.00      1.00      1.00         1
#          oni       0.00      0.00      0.00         1
#          oph       0.00      0.00      0.00         1
#          opp       0.33      0.50      0.40         2
#          oqa       0.67      1.00      0.80         2
#          pcv       1.00      1.00      1.00         1
#          pgi       1.00      1.00      1.00         3
#          pgm       1.00      1.00      1.00         2
#          pgu       0.50      0.50      0.50         2
#          pou       0.00      0.00      0.00         1
#          pqd       0.00      0.00      0.00         1
#          prb       0.67      1.00      0.80         2
#          pre       1.00      1.00      1.00         2
#          psg       0.00      0.00      0.00         1
#          ptb       0.00      0.00      0.00         2
#          pxi       1.00      1.00      1.00         1
#          pyb       0.00      0.00      0.00         1
#          qbf       1.00      1.00      1.00         1
#          qfy       1.00      1.00      1.00         1
#          qkd       0.00      0.00      0.00         1
#          qof       0.50      1.00      0.67         2
#          qqe       1.00      1.00      1.00         2
#          qsw       1.00      0.50      0.67         2
#          rgo       1.00      1.00      1.00         2
#          rmf       1.00      1.00      1.00         1
#          rvh       1.00      1.00      1.00         1
#          sdx       1.00      1.00      1.00         1
#          sfi       0.67      1.00      0.80         2
#          sgd       1.00      1.00      1.00         1
#          shh       0.50      1.00      0.67         3
#          sii       0.00      0.00      0.00         2
#          skm       0.78      0.88      0.82         8
#          slq       0.56      0.71      0.62         7
#          snn       0.00      0.00      0.00         1
#          snv       1.00      1.00      1.00         2
#          sov       1.00      1.00      1.00         1
#          sps       0.50      0.50      0.50         2
#          sqb       0.50      1.00      0.67         1
#          swe       1.00      1.00      1.00         2
#          syt       1.00      1.00      1.00         2
#          szr       1.00      0.50      0.67         2
#          tdk       0.00      0.00      0.00         1
#          tfi       0.00      0.00      0.00         1
#          tft       1.00      1.00      1.00         2
#          tjc       0.50      1.00      0.67         1
#          tkz       0.00      0.00      0.00         1
#          tmn       0.00      0.00      0.00         1
#          tsn       1.00      1.00      1.00         2
#          tvt       1.00      1.00      1.00         1
#          txk       0.50      0.50      0.50         2
#          tyw       1.00      1.00      1.00         1
#          tza       0.00      0.00      0.00         1
#          tzn       0.00      0.00      0.00         1
#          ubr       1.00      1.00      1.00         1
#          udj       0.50      1.00      0.67         1
#          uey       1.00      0.50      0.67         2
#          ulu       1.00      1.00      1.00         2
#          uof       0.00      0.00      0.00         1
#          usg       1.00      1.00      1.00         1
#          usy       1.00      1.00      1.00         1
#          uwp       0.00      0.00      0.00         1
#          uwr       1.00      1.00      1.00         2
#          vek       1.00      0.50      0.67         2
#          vfo       1.00      1.00      1.00         4
#          vjw       1.00      1.00      1.00         1
#          vlm       1.00      1.00      1.00         3
#          vmy       0.00      0.00      0.00         1
#          vsb       0.00      0.00      0.00         1
#          vyu       0.50      1.00      0.67         1
#          vzc       0.50      1.00      0.67         1
#          wcf       0.00      0.00      0.00         1
#          wem       1.00      1.00      1.00         2
#          wfs       0.50      0.50      0.50         2
#          wht       0.20      0.50      0.29         2
#          wjn       0.50      0.50      0.50         2
#          wuy       1.00      1.00      1.00         1
#          wvy       1.00      1.00      1.00         1
#          wwk       1.00      1.00      1.00         1
#          wxf       0.00      0.00      0.00         1
#          xby       1.00      1.00      1.00         1
#          xgb       0.00      0.00      0.00         1
#          xgv       1.00      0.50      0.67         2
#          xkr       0.00      0.00      0.00         1
#          xvr       0.50      1.00      0.67         1
#          xwz       1.00      1.00      1.00         1
#          ycb       0.00      0.00      0.00         1
#          ykq       0.00      0.00      0.00         1
#          yrb       0.00      0.00      0.00         1
#          yuz       0.67      1.00      0.80         2
#          yvq       0.50      1.00      0.67         1
#          zbn       1.00      0.50      0.67         2
#          zct       0.00      0.00      0.00         1
#          zht       1.00      1.00      1.00         1
#          zok       0.00      0.00      0.00         1
#          zqs       0.50      0.50      0.50         2
#          zro       0.50      1.00      0.67         1
#          zrx       1.00      1.00      1.00         1
#          zus       1.00      1.00      1.00         1
#          zyk       0.67      1.00      0.80         2
#
#    micro avg       0.72      0.71      0.71       328
#    macro avg       0.65      0.68      0.65       328
# weighted avg       0.68      0.71      0.67       328
#
# Submission saved to submission.csv (324 rows)

# %% [markdown]
# Version clean

# %%
# -*- coding: utf-8 -*-
"""
Simplified MLP pipeline — shows only F1 evolution and F1 per epoch
"""

# ============================
# CONFIG
# ============================
CONFIG = {
    "hidden_layers": [512, 256, 128, 64],
    "activation": "tanh",
    "dropout_rate": 0.2,
    "epochs": 65,
    "batch_size": 32,
    "optimizer": "adam",
    "loss": "categorical_crossentropy",
    "test_size": 0.1,
    "random_state": 42,
    "top_k_actions": 50,
    "use_browser_ohe": True,
    "train_file": "train.csv"
}

# ============================
# Imports
# ============================
import re, os
import numpy as np
import pandas as pd
from collections import Counter
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", message="The number of unique classes is greater than 50%")

# ============================
# Utils
# ============================
def read_ds(ds_name: str):
    sessions = []
    with open(ds_name, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if not line: continue
            parts = line.split(',')
            util = parts[0]
            browser = parts[1] if len(parts) > 1 else ""
            actions = parts[2:]
            sessions.append({"util": util, "browser": browser, "parts": actions})
    return pd.DataFrame(sessions)

def filter_action(value: str):
    if not isinstance(value, str): return ""
    if value.startswith("t") and value[1:].isdigit(): return ""
    for delim in ["(", "<", "$", "1"]:
        if delim in value:
            value = value.split(delim)[0]
    return value.strip()

# ============================
# Feature engineering
# ============================
def session_to_features(parts):
    times, actions_clean, timeline = [], [], []
    current_time = 0
    for token in parts:
        tok = token.strip()
        m = re.match(r'^t(\d+)$', tok)
        if m:
            current_time = int(m.group(1))
            continue
        timeline.append((current_time, tok))
        a = filter_action(tok)
        if a:
            actions_clean.append(a)

    if not timeline:
        return {k:0.0 for k in [
            "nb_actions","nb_actions_unique","temps_total","moyenne_delta","std_delta",
            "delta_min","delta_max","delta_median","taux_repetition",
            "longueur_moyenne_sequence","longest_repeat","diversite_actions",
            "top3_ratio","unique_transitions","actions_joined"
        ]}

    times_list = [t for t,_ in timeline]
    deltas = [0.0] + [times_list[i]-times_list[i-1] for i in range(1,len(times_list))]
    nb_actions = len(timeline)
    nb_actions_unique = len(set(actions_clean))
    temps_total = float(times_list[-1]-times_list[0]) if len(times_list)>1 else 0.0
    moyenne_delta = float(np.mean(deltas))
    std_delta = float(np.std(deltas, ddof=1)) if len(deltas)>1 else 0.0
    delta_min = float(np.min(deltas))
    delta_max = float(np.max(deltas))
    delta_median = float(np.median(deltas))

    rep_flags = [1 if actions_clean[i]==actions_clean[i-1] else 0 for i in range(1,len(actions_clean))]
    taux_repetition = float(np.mean(rep_flags)) if rep_flags else 0.0
    seqs, cur = [], 1
    for i in range(1,len(actions_clean)):
        if actions_clean[i]==actions_clean[i-1]: cur+=1
        else: seqs.append(cur); cur=1
    if actions_clean: seqs.append(cur)
    longueur_moy_seq = float(np.mean(seqs)) if seqs else 0.0
    longest_repeat = float(max(seqs)) if seqs else 0.0

    diversite = float(nb_actions_unique/nb_actions) if nb_actions>0 else 0.0

    counts = Counter(actions_clean)
    top3_ratio = sum([counts[a] for a,_ in counts.most_common(3)]) / nb_actions
    bigrams = list(zip(actions_clean[:-1], actions_clean[1:]))
    unique_transitions = len(set(bigrams))

    return {
        "nb_actions": nb_actions,
        "nb_actions_unique": nb_actions_unique,
        "temps_total": temps_total,
        "moyenne_delta": moyenne_delta,
        "std_delta": std_delta,
        "delta_min": delta_min,
        "delta_max": delta_max,
        "delta_median": delta_median,
        "taux_repetition": taux_repetition,
        "longueur_moyenne_sequence": longueur_moy_seq,
        "longest_repeat": longest_repeat,
        "diversite_actions": diversite,
        "top3_ratio": top3_ratio,
        "unique_transitions": unique_transitions,
        "actions_joined": " ".join([a.replace(" ","_") for a in actions_clean])
    }

# ============================
# Main pipeline
# ============================
def main_pipeline(config=CONFIG):
    print("Loading data...")
    train_raw = read_ds(config["train_file"])

    print("Building enriched features...")
    rows = []
    for _, row in train_raw.iterrows():
        feats = session_to_features(row["parts"])
        feats["browser"] = row["browser"]
        feats["util"] = row["util"]
        rows.append(feats)
    train_basic = pd.DataFrame(rows)
    train_basic = train_basic[train_basic["nb_actions"]>0].reset_index(drop=True)

    # Vectorisation
    vectorizer = CountVectorizer(max_features=config["top_k_actions"])
    vectorizer.fit(train_basic["actions_joined"].fillna(""))
    X_actions = vectorizer.transform(train_basic["actions_joined"].fillna("")).toarray()

    numeric_cols = [
        "nb_actions","nb_actions_unique","temps_total","moyenne_delta","std_delta",
        "delta_min","delta_max","delta_median","taux_repetition",
        "longueur_moyenne_sequence","longest_repeat","diversite_actions",
        "top3_ratio","unique_transitions"
    ]
    scaler = StandardScaler()
    X_num = scaler.fit_transform(train_basic[numeric_cols].fillna(0).values)

    if config["use_browser_ohe"]:
        ohe = OneHotEncoder(sparse_output=False, handle_unknown="ignore")
        X_browser = ohe.fit_transform(train_basic[["browser"]].fillna("UNK"))
    else:
        X_browser = np.zeros((len(train_basic),0))

    X_full = np.hstack([X_num, X_browser, X_actions])

    label_encoder = LabelEncoder()
    y = label_encoder.fit_transform(train_basic["util"].astype(str))
    n_classes = len(label_encoder.classes_)

    X_tr, X_val, y_tr, y_val = train_test_split(
        X_full, y, test_size=config["test_size"],
        random_state=config["random_state"], stratify=y
    )

    # === MLP Model ===
    tf.keras.backend.clear_session()
    model = Sequential()
    model.add(Dense(config["hidden_layers"][0], activation=config["activation"], input_shape=(X_tr.shape[1],)))
    model.add(Dropout(config["dropout_rate"]))
    for neurons in config["hidden_layers"][1:]:
        model.add(Dense(neurons, activation=config["activation"]))
        model.add(Dropout(config["dropout_rate"]))
    model.add(Dense(n_classes, activation='softmax'))
    model.compile(optimizer=config["optimizer"], loss=config["loss"], metrics=['accuracy'])

    # === Training loop with F1 ===
    f1_tr_list, f1_val_list = [], []
    for epoch in range(config["epochs"]):
        model.fit(X_tr, tf.keras.utils.to_categorical(y_tr, n_classes),
                  validation_data=(X_val, tf.keras.utils.to_categorical(y_val, n_classes)),
                  epochs=1, batch_size=config["batch_size"], verbose=0)

        y_pred_tr = np.argmax(model.predict(X_tr, verbose=0), axis=1)
        y_pred_val = np.argmax(model.predict(X_val, verbose=0), axis=1)
        f1_tr = f1_score(y_tr, y_pred_tr, average='macro', zero_division=0)
        f1_val = f1_score(y_val, y_pred_val, average='macro', zero_division=0)
        f1_tr_list.append(f1_tr)
        f1_val_list.append(f1_val)
        print(f"Epoch {epoch+1:02d}/{config['epochs']} — F1 train: {f1_tr:.4f} | F1 val: {f1_val:.4f}")

    # === Plot F1 evolution ===
    plt.figure(figsize=(8,5))
    plt.plot(range(1, config["epochs"]+1), f1_tr_list, label="F1 train")
    plt.plot(range(1, config["epochs"]+1), f1_val_list, label="F1 val")
    plt.xlabel("Epoch")
    plt.ylabel("F1 score (macro)")
    plt.title("F1 score evolution per epoch")
    plt.grid(True)
    plt.legend()
    plt.show()

if __name__ == "__main__":
    main_pipeline(CONFIG)
# Out:
# Loading data...
# Building enriched features...
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 01/200 — F1 train: 0.0002 | F1 val: 0.0002
# Epoch 02/200 — F1 train: 0.0002 | F1 val: 0.0002
# Epoch 03/200 — F1 train: 0.0007 | F1 val: 0.0011
# Epoch 04/200 — F1 train: 0.0016 | F1 val: 0.0024
# Epoch 05/200 — F1 train: 0.0050 | F1 val: 0.0069
# Epoch 06/200 — F1 train: 0.0067 | F1 val: 0.0065
# Epoch 07/200 — F1 train: 0.0097 | F1 val: 0.0093
# Epoch 08/200 — F1 train: 0.0180 | F1 val: 0.0229
# Epoch 09/200 — F1 train: 0.0198 | F1 val: 0.0225
# Epoch 10/200 — F1 train: 0.0320 | F1 val: 0.0333
# Epoch 11/200 — F1 train: 0.0495 | F1 val: 0.0387
# Epoch 12/200 — F1 train: 0.0537 | F1 val: 0.0471
# Epoch 13/200 — F1 train: 0.0708 | F1 val: 0.0585
# Epoch 14/200 — F1 train: 0.0974 | F1 val: 0.0841
# Epoch 15/200 — F1 train: 0.0982 | F1 val: 0.0942
# Epoch 16/200 — F1 train: 0.1157 | F1 val: 0.0848
# Epoch 17/200 — F1 train: 0.1445 | F1 val: 0.1323
# Epoch 18/200 — F1 train: 0.1387 | F1 val: 0.1183
# Epoch 19/200 — F1 train: 0.1621 | F1 val: 0.1510
# Epoch 20/200 — F1 train: 0.1700 | F1 val: 0.1637
# Epoch 21/200 — F1 train: 0.1901 | F1 val: 0.2061
# Epoch 22/200 — F1 train: 0.2085 | F1 val: 0.1947
# Epoch 23/200 — F1 train: 0.2186 | F1 val: 0.1800
# Epoch 24/200 — F1 train: 0.2394 | F1 val: 0.2009
# Epoch 25/200 — F1 train: 0.2603 | F1 val: 0.2367
# Epoch 26/200 — F1 train: 0.2569 | F1 val: 0.2342
# Epoch 27/200 — F1 train: 0.2714 | F1 val: 0.2540
# Epoch 28/200 — F1 train: 0.2847 | F1 val: 0.2413
# Epoch 29/200 — F1 train: 0.3083 | F1 val: 0.2715
# Epoch 30/200 — F1 train: 0.3241 | F1 val: 0.2882
# Epoch 31/200 — F1 train: 0.3257 | F1 val: 0.2788
# Epoch 32/200 — F1 train: 0.3469 | F1 val: 0.2882
# Epoch 33/200 — F1 train: 0.3624 | F1 val: 0.2997
# Epoch 34/200 — F1 train: 0.3745 | F1 val: 0.3128
# Epoch 35/200 — F1 train: 0.3817 | F1 val: 0.3268
# Epoch 36/200 — F1 train: 0.4029 | F1 val: 0.3303
# Epoch 37/200 — F1 train: 0.3963 | F1 val: 0.3472
# Epoch 38/200 — F1 train: 0.4070 | F1 val: 0.3511
# Epoch 39/200 — F1 train: 0.4248 | F1 val: 0.3676
# Epoch 40/200 — F1 train: 0.4572 | F1 val: 0.3679
# Epoch 41/200 — F1 train: 0.4520 | F1 val: 0.3781
# Epoch 42/200 — F1 train: 0.4572 | F1 val: 0.3738
# Epoch 43/200 — F1 train: 0.4510 | F1 val: 0.3736
# Epoch 44/200 — F1 train: 0.4692 | F1 val: 0.3720
# Epoch 45/200 — F1 train: 0.4773 | F1 val: 0.3862
# Epoch 46/200 — F1 train: 0.4966 | F1 val: 0.4122
# Epoch 47/200 — F1 train: 0.5038 | F1 val: 0.4064
# Epoch 48/200 — F1 train: 0.5004 | F1 val: 0.4223
# Epoch 49/200 — F1 train: 0.5173 | F1 val: 0.4195
# Epoch 50/200 — F1 train: 0.5242 | F1 val: 0.4355
# Epoch 51/200 — F1 train: 0.5502 | F1 val: 0.4667
# Epoch 52/200 — F1 train: 0.5395 | F1 val: 0.4603
# Epoch 53/200 — F1 train: 0.5498 | F1 val: 0.4622
# Epoch 54/200 — F1 train: 0.5713 | F1 val: 0.4604
# Epoch 55/200 — F1 train: 0.5633 | F1 val: 0.4609
# Epoch 56/200 — F1 train: 0.5577 | F1 val: 0.4587
# Epoch 57/200 — F1 train: 0.5719 | F1 val: 0.4584
# Epoch 58/200 — F1 train: 0.5928 | F1 val: 0.4966
# Epoch 59/200 — F1 train: 0.5863 | F1 val: 0.4803
# Epoch 60/200 — F1 train: 0.6006 | F1 val: 0.4757
# Epoch 61/200 — F1 train: 0.5998 | F1 val: 0.4667
# Epoch 62/200 — F1 train: 0.6095 | F1 val: 0.4826
# Epoch 63/200 — F1 train: 0.5999 | F1 val: 0.4699
# Epoch 64/200 — F1 train: 0.6026 | F1 val: 0.4624
# Epoch 65/200 — F1 train: 0.6210 | F1 val: 0.5059
# Epoch 66/200 — F1 train: 0.6196 | F1 val: 0.4654
# Epoch 67/200 — F1 train: 0.6343 | F1 val: 0.4945
# Epoch 68/200 — F1 train: 0.6374 | F1 val: 0.4745
# Epoch 69/200 — F1 train: 0.6397 | F1 val: 0.5152
# Epoch 70/200 — F1 train: 0.6296 | F1 val: 0.4879
# Epoch 71/200 — F1 train: 0.6289 | F1 val: 0.4911
# Epoch 72/200 — F1 train: 0.6560 | F1 val: 0.4882
# Epoch 73/200 — F1 train: 0.6650 | F1 val: 0.5098
# Epoch 74/200 — F1 train: 0.6547 | F1 val: 0.5191
# Epoch 75/200 — F1 train: 0.6586 | F1 val: 0.4817
# Epoch 76/200 — F1 train: 0.6734 | F1 val: 0.5196
# Epoch 77/200 — F1 train: 0.6654 | F1 val: 0.5383
# Epoch 78/200 — F1 train: 0.6802 | F1 val: 0.5292
# Epoch 79/200 — F1 train: 0.6774 | F1 val: 0.5263
# Epoch 80/200 — F1 train: 0.6819 | F1 val: 0.5145
# Epoch 81/200 — F1 train: 0.6947 | F1 val: 0.5471
# Epoch 82/200 — F1 train: 0.6985 | F1 val: 0.5303
# Epoch 83/200 — F1 train: 0.6932 | F1 val: 0.5254
# Epoch 84/200 — F1 train: 0.7014 | F1 val: 0.5184
# Epoch 85/200 — F1 train: 0.7159 | F1 val: 0.5324
# Epoch 86/200 — F1 train: 0.7081 | F1 val: 0.5339
# Epoch 87/200 — F1 train: 0.7209 | F1 val: 0.5266
# Epoch 88/200 — F1 train: 0.7203 | F1 val: 0.5372
# Epoch 89/200 — F1 train: 0.7298 | F1 val: 0.5226
# Epoch 90/200 — F1 train: 0.7178 | F1 val: 0.5193
# Epoch 91/200 — F1 train: 0.7333 | F1 val: 0.5307
# Epoch 92/200 — F1 train: 0.7382 | F1 val: 0.5527
# Epoch 93/200 — F1 train: 0.7326 | F1 val: 0.5382
# Epoch 94/200 — F1 train: 0.7459 | F1 val: 0.5484
# Epoch 95/200 — F1 train: 0.7389 | F1 val: 0.5413
# Epoch 96/200 — F1 train: 0.7451 | F1 val: 0.5497
# Epoch 97/200 — F1 train: 0.7555 | F1 val: 0.5540
# Epoch 98/200 — F1 train: 0.7564 | F1 val: 0.5486
# Epoch 99/200 — F1 train: 0.7527 | F1 val: 0.5504
# Epoch 100/200 — F1 train: 0.7629 | F1 val: 0.5449
# Epoch 101/200 — F1 train: 0.7512 | F1 val: 0.5670
# Epoch 102/200 — F1 train: 0.7724 | F1 val: 0.5682
# Epoch 103/200 — F1 train: 0.7803 | F1 val: 0.5824
# Epoch 104/200 — F1 train: 0.7844 | F1 val: 0.5768
# Epoch 105/200 — F1 train: 0.7708 | F1 val: 0.5545
# Epoch 106/200 — F1 train: 0.7750 | F1 val: 0.5810
# Epoch 107/200 — F1 train: 0.7817 | F1 val: 0.5645
# Epoch 108/200 — F1 train: 0.7873 | F1 val: 0.5522
# Epoch 109/200 — F1 train: 0.7947 | F1 val: 0.5659
# Epoch 110/200 — F1 train: 0.8004 | F1 val: 0.5658
# Epoch 111/200 — F1 train: 0.8017 | F1 val: 0.5481
# Epoch 112/200 — F1 train: 0.7957 | F1 val: 0.5804
# Epoch 113/200 — F1 train: 0.7989 | F1 val: 0.5570
# Epoch 114/200 — F1 train: 0.8144 | F1 val: 0.5844
# Epoch 115/200 — F1 train: 0.8190 | F1 val: 0.5824
# Epoch 116/200 — F1 train: 0.8122 | F1 val: 0.5816
# Epoch 117/200 — F1 train: 0.8174 | F1 val: 0.5629
# Epoch 118/200 — F1 train: 0.8261 | F1 val: 0.5730
# Epoch 119/200 — F1 train: 0.8169 | F1 val: 0.5642
# Epoch 120/200 — F1 train: 0.8215 | F1 val: 0.5889
# Epoch 121/200 — F1 train: 0.8314 | F1 val: 0.5761
# Epoch 122/200 — F1 train: 0.8192 | F1 val: 0.5863
# Epoch 123/200 — F1 train: 0.8267 | F1 val: 0.5776
# Epoch 124/200 — F1 train: 0.8395 | F1 val: 0.5998
# Epoch 125/200 — F1 train: 0.8460 | F1 val: 0.5688
# Epoch 126/200 — F1 train: 0.8391 | F1 val: 0.5914
# Epoch 127/200 — F1 train: 0.8388 | F1 val: 0.5873
# Epoch 128/200 — F1 train: 0.8410 | F1 val: 0.5685
# Epoch 129/200 — F1 train: 0.8433 | F1 val: 0.5880
# Epoch 130/200 — F1 train: 0.8417 | F1 val: 0.5874
# Epoch 131/200 — F1 train: 0.8512 | F1 val: 0.5823
# Epoch 132/200 — F1 train: 0.8538 | F1 val: 0.6074
# Epoch 133/200 — F1 train: 0.8592 | F1 val: 0.6027
# Epoch 134/200 — F1 train: 0.8493 | F1 val: 0.6013
# Epoch 135/200 — F1 train: 0.8565 | F1 val: 0.6085
# Epoch 136/200 — F1 train: 0.8563 | F1 val: 0.6013
# Epoch 137/200 — F1 train: 0.8743 | F1 val: 0.5979
# Epoch 138/200 — F1 train: 0.8618 | F1 val: 0.6063
# Epoch 139/200 — F1 train: 0.8655 | F1 val: 0.5930
# Epoch 140/200 — F1 train: 0.8689 | F1 val: 0.5789
# Epoch 141/200 — F1 train: 0.8720 | F1 val: 0.6082
# Epoch 142/200 — F1 train: 0.8742 | F1 val: 0.5983
# Epoch 143/200 — F1 train: 0.8630 | F1 val: 0.5923
# Epoch 144/200 — F1 train: 0.8697 | F1 val: 0.5897
# Epoch 145/200 — F1 train: 0.8866 | F1 val: 0.6229
# Epoch 146/200 — F1 train: 0.8795 | F1 val: 0.5938
# Epoch 147/200 — F1 train: 0.8768 | F1 val: 0.5857
# Epoch 148/200 — F1 train: 0.8763 | F1 val: 0.5849
# Epoch 149/200 — F1 train: 0.8799 | F1 val: 0.5981
# Epoch 150/200 — F1 train: 0.8832 | F1 val: 0.6116
# Epoch 151/200 — F1 train: 0.8798 | F1 val: 0.6154
# Epoch 152/200 — F1 train: 0.8823 | F1 val: 0.5966
# Epoch 153/200 — F1 train: 0.8879 | F1 val: 0.6074
# Epoch 154/200 — F1 train: 0.8945 | F1 val: 0.6122
# Epoch 155/200 — F1 train: 0.8887 | F1 val: 0.6266
# Epoch 156/200 — F1 train: 0.8965 | F1 val: 0.6246
# Epoch 157/200 — F1 train: 0.8883 | F1 val: 0.6216
# Epoch 158/200 — F1 train: 0.8989 | F1 val: 0.6099
# Epoch 159/200 — F1 train: 0.9125 | F1 val: 0.6037
# Epoch 160/200 — F1 train: 0.9055 | F1 val: 0.6241
# Epoch 161/200 — F1 train: 0.8953 | F1 val: 0.6000
# Epoch 162/200 — F1 train: 0.9059 | F1 val: 0.5998
# Epoch 163/200 — F1 train: 0.9175 | F1 val: 0.6231
# Epoch 164/200 — F1 train: 0.9070 | F1 val: 0.6038
# Epoch 165/200 — F1 train: 0.9076 | F1 val: 0.6249
# Epoch 166/200 — F1 train: 0.9138 | F1 val: 0.5929
# Epoch 167/200 — F1 train: 0.9119 | F1 val: 0.6314
# Epoch 168/200 — F1 train: 0.9197 | F1 val: 0.6413
# Epoch 169/200 — F1 train: 0.9150 | F1 val: 0.6336
# Epoch 170/200 — F1 train: 0.9170 | F1 val: 0.6155
# Epoch 171/200 — F1 train: 0.9148 | F1 val: 0.6075
# Epoch 172/200 — F1 train: 0.9102 | F1 val: 0.5998
# Epoch 173/200 — F1 train: 0.9278 | F1 val: 0.6151
# Epoch 174/200 — F1 train: 0.9234 | F1 val: 0.6310
# Epoch 175/200 — F1 train: 0.9197 | F1 val: 0.6195
# Epoch 176/200 — F1 train: 0.9230 | F1 val: 0.6260
# Epoch 177/200 — F1 train: 0.9340 | F1 val: 0.6306
# Epoch 178/200 — F1 train: 0.9334 | F1 val: 0.6043
# Epoch 179/200 — F1 train: 0.9229 | F1 val: 0.6125
# Epoch 180/200 — F1 train: 0.9272 | F1 val: 0.6087
# Epoch 181/200 — F1 train: 0.9117 | F1 val: 0.6066
# Epoch 182/200 — F1 train: 0.9337 | F1 val: 0.6374
# Epoch 183/200 — F1 train: 0.9183 | F1 val: 0.6129
# Epoch 184/200 — F1 train: 0.9326 | F1 val: 0.6346
# Epoch 185/200 — F1 train: 0.9316 | F1 val: 0.6000
# Epoch 186/200 — F1 train: 0.9381 | F1 val: 0.6021
# Epoch 187/200 — F1 train: 0.9395 | F1 val: 0.6056
# Epoch 188/200 — F1 train: 0.9342 | F1 val: 0.6248
# Epoch 189/200 — F1 train: 0.9332 | F1 val: 0.6161
# Epoch 190/200 — F1 train: 0.9347 | F1 val: 0.6192
# Epoch 191/200 — F1 train: 0.9240 | F1 val: 0.6194
# Epoch 192/200 — F1 train: 0.9301 | F1 val: 0.6057
# Epoch 193/200 — F1 train: 0.9435 | F1 val: 0.6092
# Epoch 194/200 — F1 train: 0.9361 | F1 val: 0.6129
# Epoch 195/200 — F1 train: 0.9452 | F1 val: 0.5993
# Epoch 196/200 — F1 train: 0.9400 | F1 val: 0.6411
# Epoch 197/200 — F1 train: 0.9435 | F1 val: 0.6151
# Epoch 198/200 — F1 train: 0.9390 | F1 val: 0.6440
# Epoch 199/200 — F1 train: 0.9332 | F1 val: 0.6406
# Epoch 200/200 — F1 train: 0.9413 | F1 val: 0.6313
